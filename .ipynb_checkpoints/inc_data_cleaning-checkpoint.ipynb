# %%
import numpy as np
import pandas as pd

# %%
inc_df = pd.read_csv('inc_data.csv', sep='|')

# %%
inc_df.head(10)
# Out:
#    Rank_2017                      Company_Name Revenue_2016  \
# 0          1                            Skillz      $54.2 M
# 1          2                 EnviroSolar Power      $37.4 M
# 2          3                          Gametime      $48.8 M
# 3          4            Club Pilates Franchise      $26.8 M
# 4          5                 Halo Top Creamery      $49.1 M
# 5          6  Small Business Owners of America      $19.7 M
# 6          7              AutomotiveMastermind      $23.2 M
# 7          8                           Liftoff      $59.6 M
# 8          9                        Greenspire      $41.7 M
# 9         10          FormulaFolio Investments      $17.2 M
#
#                        Industry  Employees  Founded Growth_3_yrs  \
# 0                      Software       58.0   2012.0      50,059%
# 1                        Energy       85.0   2012.0      36,065%
# 2  Consumer Products & Services       75.0   2013.0      34,021%
# ...

# %%
analysis_df = inc_df[['Rank_2017', 'Company_Name', 'Revenue_2016', 'Industry', 'Employees', 'Founded', 'Growth_3_yrs', 'City', 'State']]

# %%
analysis_df.head(10)
# Out:
#    Rank_2017                      Company_Name Revenue_2016  \
# 0          1                            Skillz      $54.2 M
# 1          2                 EnviroSolar Power      $37.4 M
# 2          3                          Gametime      $48.8 M
# 3          4            Club Pilates Franchise      $26.8 M
# 4          5                 Halo Top Creamery      $49.1 M
# 5          6  Small Business Owners of America      $19.7 M
# 6          7              AutomotiveMastermind      $23.2 M
# 7          8                           Liftoff      $59.6 M
# 8          9                        Greenspire      $41.7 M
# 9         10          FormulaFolio Investments      $17.2 M
#
#                        Industry  Employees  Founded Growth_3_yrs  \
# 0                      Software       58.0   2012.0      50,059%
# 1                        Energy       85.0   2012.0      36,065%
# 2  Consumer Products & Services       75.0   2013.0      34,021%
# ...

# %%
analysis_df.columns = ['rank','name','revenue','industry','employees','founded','growth','city','state']
analysis_df.head(2)
# Out:
#    rank               name  revenue  industry  employees  founded   growth  \
# 0     1             Skillz  $54.2 M  Software       58.0   2012.0  50,059%
# 1     2  EnviroSolar Power  $37.4 M    Energy       85.0   2012.0  36,065%
#
#             city state
# 0  San Francisco    CA
# 1     Fort Worth    TX

# %%
analysis_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4997 entries, 0 to 4996
# Data columns (total 9 columns):
# rank         4997 non-null int64
# name         4997 non-null object
# revenue      4997 non-null object
# industry     4993 non-null object
# employees    4861 non-null float64
# founded      4994 non-null float64
# growth       4997 non-null object
# city         4996 non-null object
# state        4997 non-null object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 351.4+ KB

# %%
analysis_df['industry'].value_counts()
# Out:
# IT Services                     598
# Advertising & Marketing         493
# Business Products & Services    474
# Health                          395
# Software                        328
# Construction                    301
# Financial Services              262
# Government Services             240
# Consumer Products & Services    239
# Real Estate                     197
# Human Resources                 186
# Retail                          168
# Logistics & Transportation      149
# Manufacturing                   145
# Food & Beverage                 137
# Energy                           91
# Insurance                        89
# Telecommunications               86
# Education                        74
# Security                         68
# Engineering                      67
# Media                            65
# Travel & Hospitality             63
# Environmental Services           42
# Computer Hardware                36
# Name: industry, dtype: int64

# %%
analysis_df.groupby('industry').describe()
# Out:
#                              employees                                         \
#                                  count         mean           std  min    25%
# industry
# Advertising & Marketing          465.0    65.503226     88.463053  1.0  20.00
# Business Products & Services     463.0   272.166307   1875.947653  1.0  20.00
# Computer Hardware                 35.0    52.257143     75.076958  4.0  15.50
# Construction                     297.0    88.548822    154.630876  2.0  19.00
# Consumer Products & Services     236.0   114.576271    367.425961  2.0  15.00
# Education                         73.0   529.082192   2859.930893  3.0  18.00
# Energy                            89.0   130.112360    255.302781  4.0  28.00
# Engineering                       66.0   139.000000    193.745749  2.0  31.25
# Environmental Services            41.0   120.463415    192.699130  7.0  22.00
# Financial Services               259.0   274.274131    699.960717  2.0  25.00
# ...

# %%
# check if all 'revenue' values are in M (million)
analysis_df['revenue'].apply(lambda x: x[-1]).value_counts()
# Out:
# M    4997
# Name: revenue, dtype: int64

# %%
# check if all 'revenue' values are in $
analysis_df['revenue'].apply(lambda x: x[0]).value_counts()
# Out:
# $    4997
# Name: revenue, dtype: int64

# %%
#check if there is space between $ sign and amount for any row
analysis_df['revenue'].apply(lambda x: x[1]).value_counts()
# Out:
# 1    1138
# 2    1015
# 3     738
# 4     566
# 5     445
# 6     348
# 7     311
# 8     256
# 9     180
# Name: revenue, dtype: int64

# %%
# and there sum is equal to total number of rows
analysis_df['revenue'].apply(lambda x: x[1]).value_counts().values.sum()
# Out:
# 4997

# %%
# check if all row values for 'revenue' has space between amount and 'M'
analysis_df['revenue'].apply(lambda x: x[-2]).value_counts()
# Out:
#      4997
# Name: revenue, dtype: int64

# %%
# change 'revenue' column format to numerical values by removing $ and M
analysis_df.loc[:,('revenue')] = analysis_df['revenue'].apply(lambda x: x[1:-2]).values
# Out:
# /anaconda/lib/python3.6/site-packages/pandas/core/indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
analysis_df.head(10)
# Out:
#    rank                              name revenue  \
# 0     1                            Skillz    54.2
# 1     2                 EnviroSolar Power    37.4
# 2     3                          Gametime    48.8
# 3     4            Club Pilates Franchise    26.8
# 4     5                 Halo Top Creamery    49.1
# 5     6  Small Business Owners of America    19.7
# 6     7              AutomotiveMastermind    23.2
# 7     8                           Liftoff    59.6
# 8     9                        Greenspire    41.7
# 9    10          FormulaFolio Investments    17.2
#
#                        industry  employees  founded   growth           city  \
# 0                      Software       58.0   2012.0  50,059%  San Francisco
# 1                        Energy       85.0   2012.0  36,065%     Fort Worth
# 2  Consumer Products & Services       75.0   2013.0  34,021%  San Francisco
# 3  Consumer Products & Services       31.0   2007.0  21,319%     Costa Mesa
# ...

# %%
analysis_df['city'].value_counts()
# Out:
# New York City        162
# Atlanta              107
# Chicago              107
# Houston               85
# Austin                83
# San Diego             70
# Dallas                56
# San Francisco         54
# Portland              47
# Denver                45
# Irvine                44
# Seattle               43
# Tampa                 43
# Los Angeles           42
# Washington            42
# Boston                41
# Phoenix               40
# Orlando               36
# Indianapolis          30
# McLean                30
# Arlington             28
# Alpharetta            27
# Columbus              27
# Charlotte             27
# Philadelphia          26
# Minneapolis           26
# Nashville             25
# Cincinnati            25
# Scottsdale            25
# Plano                 24
#                     ...
# tempe                  1
# Coralville             1
# Dickinson              1
# Kenilworth             1
# Nampa                  1
# North Brunswick        1
# ...

# %%
analysis_df['revenue']
# Out:
# 0        54.2
# 1        37.4
# 2        48.8
# 3        26.8
# 4        49.1
# 5        19.7
# 6        23.2
# 7        59.6
# 8        41.7
# 9        17.2
# 10       13.8
# 11       13.1
# 12       24.4
# 13       25.8
# 14       28.3
# 15       59.2
# 16       46.5
# 17       15.7
# 18       16.8
# 19       32.9
# 20       12.1
# 21       29.3
# 22       59.3
# 23       65.7
# 24       20.5
# 25       19.2
# 26       29.8
# 27       11.4
# 28       15.1
# 29       19.1
#         ...
# 4967      9.2
# 4968     10.3
# 4969        4
# 4970     31.3
# 4971       10
# 4972        6
# 4973    159.5
# 4974      7.7
# 4975     10.7
# 4976      4.5
# 4977     16.3
# 4978      2.8
# 4979    233.4
# 4980     88.8
# 4981     88.3
# 4982     17.7
# 4983       15
# 4984     12.8
# 4985      6.4
# 4986     10.6
# 4987    380.5
# 4988       23
# 4989     18.5
# 4990     18.7
# 4991       31
# 4992      4.9
# 4993      6.2
# 4994    639.1
# 4995    232.1
# 4996       30
# ...

# %%
analysis_df.loc[:,('revenue')] = analysis_df['revenue'].apply(pd.to_numeric)
# Out:
# /anaconda/lib/python3.6/site-packages/pandas/core/indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
analysis_df['revenue'][:10]
# Out:
# 0    54.2
# 1    37.4
# 2    48.8
# 3    26.8
# 4    49.1
# 5    19.7
# 6    23.2
# 7    59.6
# 8    41.7
# 9    17.2
# Name: revenue, dtype: float64

# %%
analysis_df.groupby('industry').describe()['revenue']
# Out:
#                               count        mean          std  min    25%  \
# industry
# Advertising & Marketing       493.0   17.898783    35.214783  2.0  3.600
# Business Products & Services  474.0   40.125316   153.312802  2.0  4.225
# Computer Hardware              36.0   28.805556    46.864272  2.1  7.150
# Construction                  301.0   43.220266   122.608354  2.0  5.100
# Consumer Products & Services  239.0   51.448954   248.667479  1.7  4.200
# Education                      74.0   18.682432    33.681820  2.0  2.800
# Energy                         91.0   45.269231    82.487891  2.0  9.100
# Engineering                    67.0   23.829851    33.897166  2.1  5.600
# Environmental Services         42.0   24.854762    45.707726  2.1  4.200
# Financial Services            262.0  164.793511  1610.257581  1.9  5.700
# Food & Beverage               137.0   37.375182    70.207767  2.0  5.700
# Government Services           240.0   45.149167   225.562540  1.9  7.275
# ...

# %%
analysis_df['growth'].apply(lambda x: x[1]).value_counts()
# Out:
# 0    563
# 1    522
# 2    502
# 4    475
# 3    474
# 5    474
# 6    442
# ,    417
# 7    395
# 8    367
# 9    366
# Name: growth, dtype: int64

# %%
analysis_df.sort_values(by='revenue', ascending=False)
# Out:
#       rank                                               name  revenue  \
# 4022  4026                              Freepoint Commodities  26011.7
# 3515  3519                                 Prime Therapeutics   4730.2
# 1240  1242                                   Allied Universal   3431.6
# 3251  3255                               Carahsoft Technology   3429.5
# 2909  2913                                          DriveTime   3034.7
# 3645  3649                                             ARMADA   2692.7
# 4912  4916                            Total Quality Logistics   2321.1
# 3893  3897                                     Optiv Security   2045.9
# 540    542                                     Pinnacle Group   1890.1
# 4879  4883                                       Morgan Lewis   1860.0
# 2949  2953                                   SRS Distribution   1778.8
# 3667  3671                                     Insight Global   1676.7
# ...

# %%
analysis_df.loc[:,('growth')] = analysis_df['growth'].apply(lambda x: "".join(x[:-1].split(","))).values
# Out:
# /anaconda/lib/python3.6/site-packages/pandas/core/indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
analysis_df.loc[:,('growth')] = analysis_df['growth'].apply(pd.to_numeric)
# Out:
# /anaconda/lib/python3.6/site-packages/pandas/core/indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
analysis_df['growth'].head()
# Out:
# 0    50059
# 1    36065
# 2    34021
# 3    21319
# 4    20944
# Name: growth, dtype: int64

# %%
analysis_df.head()
# Out:
#    rank                    name  revenue                      industry  \
# 0     1                  Skillz     54.2                      Software
# 1     2       EnviroSolar Power     37.4                        Energy
# 2     3                Gametime     48.8  Consumer Products & Services
# 3     4  Club Pilates Franchise     26.8  Consumer Products & Services
# 4     5       Halo Top Creamery     49.1               Food & Beverage
#
#    employees  founded  growth           city state
# 0       58.0   2012.0   50059  San Francisco    CA
# 1       85.0   2012.0   36065     Fort Worth    TX
# 2       75.0   2013.0   34021  San Francisco    CA
# 3       31.0   2007.0   21319     Costa Mesa    CA
# 4       10.0   2012.0   20944    Los Angeles    CA

# %%
analysis_df[pd.isnull(analysis_df['founded'])]
# Out:
#       rank                                              name  revenue  \
# 155    156  FYZICAL Therapy & Balance Centers (Sarasota, FL)      7.8
# 4114  4118                            Southwest Capital Bank     19.0
# 4239  4243               Morris & Garritano Insurance Agency     17.2
#
#                 industry  employees  founded  growth             city state
# 155               Health       12.0      NaN    2557         Sarasota    FL
# 4114  Financial Services      100.0      NaN      66      Albuquerque    NM
# 4239           Insurance      116.0      NaN      62  San Luis Obispo    CA

# %%
analysis_df.groupby('industry').describe()[['revenue','growth']]
# Out:
#                              revenue                                       \
#                                count        mean          std  min    25%
# industry
# Advertising & Marketing        493.0   17.898783    35.214783  2.0  3.600
# Business Products & Services   474.0   40.125316   153.312802  2.0  4.225
# Computer Hardware               36.0   28.805556    46.864272  2.1  7.150
# Construction                   301.0   43.220266   122.608354  2.0  5.100
# Consumer Products & Services   239.0   51.448954   248.667479  1.7  4.200
# Education                       74.0   18.682432    33.681820  2.0  2.800
# Energy                          91.0   45.269231    82.487891  2.0  9.100
# Engineering                     67.0   23.829851    33.897166  2.1  5.600
# Environmental Services          42.0   24.854762    45.707726  2.1  4.200
# Financial Services             262.0  164.793511  1610.257581  1.9  5.700
# ...

# %%
analysis_df.to_csv('inc_cleaned_data.csv', index=False, sep='|')

# %%
dfs = pd.read_csv('inc_cleaned_data.csv', sep='|')

# %%
dfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4997 entries, 0 to 4996
# Data columns (total 9 columns):
# rank         4997 non-null int64
# name         4997 non-null object
# revenue      4997 non-null float64
# industry     4993 non-null object
# employees    4861 non-null float64
# founded      4994 non-null float64
# growth       4997 non-null int64
# city         4996 non-null object
# state        4997 non-null object
# dtypes: float64(3), int64(2), object(4)
# memory usage: 351.4+ KB

# %%
analysis_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4997 entries, 0 to 4996
# Data columns (total 9 columns):
# rank         4997 non-null int64
# name         4997 non-null object
# revenue      4997 non-null float64
# industry     4993 non-null object
# employees    4861 non-null float64
# founded      4994 non-null float64
# growth       4997 non-null int64
# city         4996 non-null object
# state        4997 non-null object
# dtypes: float64(3), int64(2), object(4)
# memory usage: 351.4+ KB
