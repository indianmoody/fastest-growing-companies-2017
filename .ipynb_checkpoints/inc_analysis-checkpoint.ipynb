# %%
import numpy as np
import pandas as pd

# %%
inc_df = pd.read_csv('inc_data.csv', sep='|')

# %%
inc_df.head(10)
# Out:
#    Rank_2017                      Company_Name Revenue_2016  \
# 0          1                            Skillz      $54.2 M
# 1          2                 EnviroSolar Power      $37.4 M
# 2          3                          Gametime      $48.8 M
# 3          4            Club Pilates Franchise      $26.8 M
# 4          5                 Halo Top Creamery      $49.1 M
# 5          6  Small Business Owners of America      $19.7 M
# 6          7              AutomotiveMastermind      $23.2 M
# 7          8                           Liftoff      $59.6 M
# 8          9                        Greenspire      $41.7 M
# 9         10          FormulaFolio Investments      $17.2 M
#
#                        Industry  Employees  Founded Growth_3_yrs  \
# 0                      Software       58.0   2012.0      50,059%
# 1                        Energy       85.0   2012.0      36,065%
# 2  Consumer Products & Services       75.0   2013.0      34,021%
# ...
